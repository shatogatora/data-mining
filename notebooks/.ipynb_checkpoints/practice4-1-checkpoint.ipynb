# %%
# !pip install pandas matplotlib statsmodels seasonal
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.11/site-packages (0.14.2)
# Collecting seasonal
#   Downloading seasonal-0.3.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/conda/lib/python3.11/site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.11/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading seasonal-0.3.1-py2.py3-none-any.whl (18 kB)
# Installing collected packages: seasonal
# Successfully installed seasonal-0.3.1

# %%
#q1-1

import pandas as pd

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# データの中身を確認
print(data.head(13))
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# 5   1949-06-01         135
# 6   1949-07-01         148
# 7   1949-08-01         148
# 8   1949-09-01         136
# 9   1949-10-01         119
# 10  1949-11-01         104
# 11  1949-12-01         118
# 12  1950-01-01         115

# %%
print(data.tail(5))
# Out:
#           Month  Passengers
# 139  1960-08-01         606
# 140  1960-09-01         508
# 141  1960-10-01         461
# 142  1960-11-01         390
# 143  1960-12-01         432

# %%
import matplotlib.pyplot as plt

# 折れ線グラフを描画
plt.figure(figsize=(10, 6))
for column in data.columns[1:]:  # 1列目以降のデータをプロット
    plt.plot(data[data.columns[0]], data[column], label=column)

# グラフの設定
plt.title("AirPassengers")
plt.xlabel("date")  # X軸ラベル
plt.ylabel("count")  # Y軸ラベル
plt.legend()  # 凡例
plt.grid(True)  # グリッド

# 5. グラフを表示
plt.show()

# %%
#q1-2
#グラフデータの準備

import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
import matplotlib.pyplot as plt

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# 加法モデルの分解
additive_result = seasonal_decompose(data['Passengers'], model='additive', period=12)

# 乗法モデルの分解
multiplicative_result = seasonal_decompose(data['Passengers'], model='multiplicative', period=12)

# STL分解
stl = STL(data['Passengers'], period=12, robust=True)
stl_result = stl.fit()

# %%
#加法モデル

plt.figure(figsize=(16, 12))

# 各コンポーネントを個別にプロット
plt.subplot(2, 2, 1)
plt.plot(additive_result.observed, label='Passengers')
plt.title('Observed')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(additive_result.trend, label='Trend', color='orange')
plt.title('Trend')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(additive_result.seasonal, label='Seasonal', color='green')
plt.title('Seasonal')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(additive_result.resid, label='Residual', color='red')
plt.title('Residual')

plt.suptitle('Additive Model - Decomposition', fontsize=14)

plt.show()

# %%
# 乗法モデル

plt.figure(figsize=(16, 12))

# 各コンポーネントを個別にプロット
plt.subplot(2, 2, 1)
plt.plot(multiplicative_result.observed, label='Passengers')
plt.title('Observed')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(multiplicative_result.trend, label='Trend', color='orange')
plt.title('Trend')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(multiplicative_result.seasonal, label='Seasonal', color='green')
plt.title('Seasonal')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(multiplicative_result.resid, label='Residual', color='red')
plt.title('Residual')
plt.legend()

plt.suptitle('Multiplicative Model - Decomposition', fontsize=14)

plt.show()

# %%
# STL分解
plt.figure(figsize=(16, 12))

# 各コンポーネントを個別にプロット
plt.subplot(2, 2, 1)
plt.plot(stl_result.observed, label='Passengers')
plt.title('Observed')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(stl_result.trend, label='Trend', color='orange')
plt.title('Trend')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(stl_result.seasonal, label='Seasonal', color='green')
plt.title('Seasonal')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(stl_result.resid, label='Residual', color='red')
plt.title('Residual')
plt.legend()

plt.suptitle('STL - Decomposition', fontsize=14)

plt.show()

# %%
# q1-3
# データ準備

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)
original_series = data['Passengers']

# 1ヶ月差分系列
diff_1 = original_series.diff(1)

# 12ヶ月差分系列
diff_12 = original_series.diff(12)

# %%
# グラフプロット

plt.figure(figsize=(10, 6))

# 原系列
plt.plot(original_series, label='Original Series')
plt.title('Original Series')
plt.legend()

plt.show()

# %%
# 1ヶ月差分系列

plt.figure(figsize=(10, 6))
plt.plot(diff_1, label='1-Month Differenced Series', color='orange')
plt.title('1-Month Differenced Series')
plt.legend()

plt.show()

# %%
# 12ヶ月差分系列

plt.figure(figsize=(10, 6))
plt.plot(diff_12, label='12-Month Differenced Series', color='green')
plt.title('12-Month Differenced Series')
plt.legend()

plt.show()

# %%
# ADF検定

# ADF検定の結果を表示する関数
def adf_test(series, series_name):
    result = adfuller(series.dropna())
    print(f"  Test Statistic: {result[0]}")
    print(f"  p-value: {result[1]}")
    print(f"  Critical Values: {result[4]}")
    print("\n")

# 原系列のADF検定
adf_test(original_series, "Original Series")

# 1ヶ月差分系列のADF検定
adf_test(diff_1, "1-Month Differenced Series")

# 12ヶ月差分系列のADF検定
adf_test(diff_12, "12-Month Differenced Series")
# Out:
#   Test Statistic: 0.8153688792060528
#   p-value: 0.9918802434376411
#   Critical Values: {'1%': np.float64(-3.4816817173418295), '5%': np.float64(-2.8840418343195267), '10%': np.float64(-2.578770059171598)}
#
#
#   Test Statistic: -2.829266824169999
#   p-value: 0.05421329028382552
#   Critical Values: {'1%': np.float64(-3.4816817173418295), '5%': np.float64(-2.8840418343195267), '10%': np.float64(-2.578770059171598)}
#
#
#   Test Statistic: -3.383020726492481
#   p-value: 0.011551493085514952
#   Critical Values: {'1%': np.float64(-3.4816817173418295), '5%': np.float64(-2.8840418343195267), '10%': np.float64(-2.578770059171598)}

# %%
# q1-4

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(10, 10))

# 原系列の自己相関(ACF)、偏自己相関(PACF)
plt.subplot(2, 1, 1)
plot_acf(original_series.dropna(), lags=40, ax=plt.gca())
plt.title('ACF of Original Series')

plt.subplot(2, 1, 2)
plot_pacf(original_series.dropna(), lags=40, ax=plt.gca(), method='ywm')
plt.title('PACF of Original Series')

plt.show()

# %%
plt.figure(figsize=(10, 10))

# 1ヶ月差分系列の自己相関(ACF)、偏自己相関(PACF)
plt.subplot(2, 1, 1)
plot_acf(diff_1.dropna(), lags=40, ax=plt.gca())
plt.title('ACF of 1-Month Differenced Series')

plt.subplot(2, 1, 2)
plot_pacf(diff_1.dropna(), lags=40, ax=plt.gca(), method='ywm')
plt.title('PACF of 1-Month Differenced Series')

plt.show()

# %%
plt.figure(figsize=(10, 10))

# 12ヶ月差分系列の自己相関(ACF)、偏自己相関(PACF)
plt.subplot(2, 1, 1)
plot_acf(diff_12.dropna(), lags=40, ax=plt.gca())
plt.title('ACF of 12-Month Differenced Series')

plt.subplot(2, 1, 2)
plot_pacf(diff_12.dropna(), lags=40, ax=plt.gca(), method='ywm')
plt.title('PACF of 12-Month Differenced Series')

plt.show()

# %%
# q1-5

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# データセットの分割
test_size = 12  # 直近12ヶ月
train = data.iloc[:-test_size]  # テストデータ以外をトレーニングデータ
test = data.iloc[-test_size:]  # 直近12ヶ月をテストデータ

# %%
print(test.head())
# Out:
#           Month  Passengers
# 132  1960-01-01         417
# 133  1960-02-01         391
# 134  1960-03-01         419
# 135  1960-04-01         461
# 136  1960-05-01         472

# %%
# グラフの描画
plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 分割点の強調
plt.axvline(test.index[0], color='red', linestyle='--', label='Split Point')

# ラベル設定
plt.title('Training and Test Data Split')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# %%
#q1-6

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 1, 1, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -625.518
# Date:                Fri, 27 Dec 2024   AIC                           1257.035
# Time:                        05:38:08   BIC                           1265.661
# Sample:                             0   HQIC                          1260.540
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5436      0.100     -5.443      0.000      -0.739      -0.348
# ma.L1          0.9272      0.051     18.336      0.000       0.828       1.026
# sigma2       816.5398     95.147      8.582      0.000     630.056    1003.024
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):                 2.51
# Prob(Q):                              0.57   Prob(JB):                         0.29
# Heteroskedasticity (H):               6.76   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 8322.701142626915

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 1, 2, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -628.931
# Date:                Fri, 27 Dec 2024   AIC                           1263.862
# Time:                        07:42:34   BIC                           1272.464
# Sample:                             0   HQIC                          1267.357
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2979      0.108      2.752      0.006       0.086       0.510
# ma.L1         -0.9999     11.491     -0.087      0.931     -23.522      21.522
# sigma2       902.6808   1.04e+04      0.087      0.931   -1.95e+04    2.13e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                 6.98
# Prob(Q):                              0.51   Prob(JB):                         0.03
# Heteroskedasticity (H):               7.39   Skew:                            -0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 6840.078366763565

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 2, 2, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(2, 2, 1)   Log Likelihood                -625.940
# Date:                Fri, 27 Dec 2024   AIC                           1259.881
# Time:                        07:43:05   BIC                           1271.351
# Sample:                             0   HQIC                          1264.541
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3621      0.098      3.689      0.000       0.170       0.554
# ar.L2         -0.2158      0.082     -2.636      0.008      -0.376      -0.055
# ma.L1         -0.9988      0.924     -1.081      0.280      -2.810       0.813
# sigma2       859.5616    826.225      1.040      0.298    -759.809    2478.932
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):                 1.17
# Prob(Q):                              0.62   Prob(JB):                         0.56
# Heteroskedasticity (H):               7.33   Skew:                            -0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 6793.570877024015

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 2, 3, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(2, 3, 1)   Log Likelihood                -646.795
# Date:                Fri, 27 Dec 2024   AIC                           1301.590
# Time:                        08:35:32   BIC                           1313.030
# Sample:                             0   HQIC                          1306.238
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2580      0.107     -2.407      0.016      -0.468      -0.048
# ar.L2         -0.2306      0.108     -2.133      0.033      -0.442      -0.019
# ma.L1         -0.9986      1.117     -0.894      0.371      -3.188       1.191
# sigma2      1269.3123   1453.944      0.873      0.383   -1580.365    4118.990
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):                16.65
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.21   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 6354.465221792293

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 2, 1, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -619.131
# Date:                Fri, 27 Dec 2024   AIC                           1246.262
# Time:                        14:20:35   BIC                           1257.763
# Sample:                             0   HQIC                          1250.936
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0698      0.094     11.323      0.000       0.885       1.255
# ar.L2         -0.4734      0.101     -4.670      0.000      -0.672      -0.275
# ma.L1         -0.8402      0.085     -9.851      0.000      -1.007      -0.673
# sigma2       741.2092     92.892      7.979      0.000     559.145     923.274
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.94   Jarque-Bera (JB):                 1.71
# Prob(Q):                              0.33   Prob(JB):                         0.42
# Heteroskedasticity (H):               6.69   Skew:                             0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 7723.663757958923

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 3, 1, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -618.726
# Date:                Fri, 27 Dec 2024   AIC                           1247.452
# Time:                        14:22:34   BIC                           1261.828
# Sample:                             0   HQIC                          1253.293
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0181      0.115      8.859      0.000       0.793       1.243
# ar.L2         -0.3859      0.137     -2.808      0.005      -0.655      -0.117
# ar.L3         -0.0851      0.102     -0.831      0.406      -0.286       0.116
# ma.L1         -0.8235      0.098     -8.380      0.000      -1.016      -0.631
# sigma2       736.2443     91.168      8.076      0.000     557.558     914.930
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.46   Jarque-Bera (JB):                 2.30
# Prob(Q):                              0.50   Prob(JB):                         0.32
# Heteroskedasticity (H):               6.65   Skew:                             0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 7671.355259681569

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 1, 1, 2

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                -622.487
# Date:                Fri, 27 Dec 2024   AIC                           1252.974
# Time:                        18:16:46   BIC                           1264.474
# Sample:                             0   HQIC                          1257.647
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5673      0.105      5.382      0.000       0.361       0.774
# ma.L1         -0.3351      0.105     -3.198      0.001      -0.540      -0.130
# ma.L2         -0.4825      0.074     -6.529      0.000      -0.627      -0.338
# sigma2       781.3644     96.191      8.123      0.000     592.834     969.894
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 0.08
# Prob(Q):                              0.80   Prob(JB):                         0.96
# Heteroskedasticity (H):               7.09   Skew:                             0.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 8281.560167402551

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# パラメータ設定
p, d, q = 2, 1, 2

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -607.782
# Date:                Fri, 27 Dec 2024   AIC                           1225.563
# Time:                        18:17:17   BIC                           1239.939
# Sample:                             0   HQIC                          1231.405
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6660      0.024     68.561      0.000       1.618       1.714
# ar.L2         -0.9294      0.022    -41.536      0.000      -0.973      -0.886
# ma.L1         -1.8324      0.032    -56.857      0.000      -1.896      -1.769
# ma.L2          0.9581      0.032     29.998      0.000       0.895       1.021
# sigma2       605.1588     73.622      8.220      0.000     460.863     749.454
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.45   Jarque-Bera (JB):                 0.78
# Prob(Q):                              0.50   Prob(JB):                         0.68
# Heteroskedasticity (H):               6.52   Skew:                             0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 3049.5619223262215

# %%
#q1-6 実験

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# データセットの分割
test_size = 12  # 直近12ヶ月
train = data.iloc[:-test_size]  # テストデータ以外をトレーニングデータ
test = data.iloc[-test_size:]  # 直近12ヶ月をテストデータ

# パラメータ設定
p, d, q = 1, 12, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('ARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# 平均二乗誤差 (MSE)
mse = mean_squared_error(test['Passengers'], forecast)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  132
# Model:                ARIMA(1, 12, 1)   Log Likelihood               -1179.124
# Date:                Sat, 28 Dec 2024   AIC                           2364.247
# Time:                        16:47:40   BIC                           2372.610
# Sample:                             0   HQIC                          2367.643
#                                 - 132
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8489      0.048    -17.616      0.000      -0.943      -0.754
# ma.L1         -1.0000      0.120     -8.349      0.000      -1.235      -0.765
# sigma2      1.966e+07   6.09e-09   3.23e+15      0.000    1.97e+07    1.97e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  68.96   Jarque-Bera (JB):                 1.51
# Prob(Q):                              0.00   Prob(JB):                         0.47
# Heteroskedasticity (H):               5.91   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.11e+30. Standard errors may be unstable.
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Mean Squared Error (MSE): 1.6408875141049405e+17

# %%
# q1-7

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# パラメータ設定
p, d, q = 1, 1, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = mean_absolute_error(test['Passengers'], forecast)
print(f"MAE: {mae}")

# MAPEの計算
mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}%")
# Out:
# RMSE: 91.22883942387361
# MAE: 66.24167467401347
# MAPE: 12.462032796976953%

# %%
# q1-7 実験

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# パラメータ設定
p, d, q = 2, 1, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = mean_absolute_error(test['Passengers'], forecast)
print(f"MAE: {mae}")

# MAPEの計算
mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}%")
# Out:
# RMSE: 87.88437721210137
# MAE: 65.2275629057783
# MAPE: 12.537934304759462%

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# パラメータ設定
p, d, q = 2, 3, 1

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = mean_absolute_error(test['Passengers'], forecast)
print(f"MAE: {mae}")

# MAPEの計算
mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}%")
# Out:
# RMSE: 79.71489962229327
# MAE: 59.9747233606472
# MAPE: 12.633737922466745%

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# パラメータ設定
p, d, q = 1, 1, 2

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = mean_absolute_error(test['Passengers'], forecast)
print(f"MAE: {mae}")

# MAPEの計算
mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}%")
# Out:
# RMSE: 91.00307779082283
# MAE: 66.8077019824646
# MAPE: 12.645418930494415%

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# パラメータ設定
p, d, q = 2, 1, 2

# ARIMAモデルの学習
model = ARIMA(train['Passengers'], order=(p, d, q))
fitted_model = model.fit()

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = mean_absolute_error(test['Passengers'], forecast)
print(f"MAE: {mae}")

# MAPEの計算
mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}%")
# Out:
# RMSE: 55.22283877460685
# MAE: 41.83479798522885
# MAPE: 8.220491088014773%

# %%
data.index = pd.to_datetime(data.index)

print(type(data.index[-1]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# 実験α

from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# インデックスに頻度情報を付与（例: 月次データの場合）
data.index = pd.date_range(start=data.index[0], periods=len(data), freq='ME')

# モデルの設定とフィッティング
model = ARIMA(data['Passengers'], order=(2, 1, 2))
fitted_model = model.fit(method_kwargs={'maxiter': 500, 'tol': 1e-6})

# フォーキャスト
forecast_steps = 12  # 12ヶ月先を予測
forecast = fitted_model.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(data.index[-1] + pd.offsets.MonthEnd(1), periods=forecast_steps, freq='ME')
forecast_values = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# 結果のプロット
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(data['Passengers'], label='Observed', color='blue')
plt.plot(forecast_index, forecast_values, label='Forecast', color='orange')
plt.fill_between(forecast_index, 
                 confidence_intervals.iloc[:, 0], 
                 confidence_intervals.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')
plt.legend()
plt.title('ARIMA(2, 1, 2) Forecast')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/base/optimizer.py:19: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score, iprint. The list of unsupported keyword arguments passed include: tol. After release 0.14, this will raise.
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# データ読み込み
file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# インデックスに頻度情報を付与（例: 月次データ）
data.index = pd.date_range(start=data.index[0], periods=len(data), freq='ME')

# モデルの設定とフィッティング
# order=(p, d, q), seasonal_order=(P, D, Q, s)
# sは季節の周期（例: 月次データなら12）
model = SARIMAX(data['Passengers'], 
                order=(1, 1, 1), 
                seasonal_order=(1, 1, 1, 12))  # 季節性を考慮
fitted_model = model.fit(disp=False)

# フォーキャスト
forecast_steps = 12  # 12ヶ月先を予測
forecast = fitted_model.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(data.index[-1] + pd.offsets.MonthEnd(1), periods=forecast_steps, freq='ME')
forecast_values = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# 結果のプロット
plt.figure(figsize=(10, 6))
plt.plot(data['Passengers'], label='Observed', color='blue')
plt.plot(forecast_index, forecast_values, label='Forecast', color='orange')
plt.fill_between(forecast_index, 
                 confidence_intervals.iloc[:, 0], 
                 confidence_intervals.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')
plt.legend()
plt.title('SARIMA(1, 1, 1)(1, 1, 1, 12) Forecast')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error

# データ読み込み
file_path = "../data/practice4-1/AirPassengers24.csv"
data = pd.read_csv(file_path)

# パラメータ設定
p, d, q = 1, 1, 1  # 非季節的なARIMAパラメータ
P, D, Q, S = 1, 1, 1, 12  # 季節的なARIMAパラメータ（Sは季節の周期）

# データセットの分割
test_size = 12  # 直近12ヶ月
train = data.iloc[:-test_size]  # テストデータ以外をトレーニングデータ
test = data.iloc[-test_size:]  # 直近12ヶ月をテストデータ

# SARIMAモデルの学習
model = SARIMAX(train['Passengers'], order=(p, d, q), seasonal_order=(P, D, Q, S))
fitted_model = model.fit()

# モデルの概要出力
print(fitted_model.summary())

# テストデータ期間の予測
forecast = fitted_model.forecast(steps=test_size)

# 予測結果のプロット
plt.figure(figsize=(12, 6))

# トレーニングデータ
plt.plot(train.index, train['Passengers'], label='Training Data', color='blue')

# テストデータ（実測値）
plt.plot(test.index, test['Passengers'], label='Test Data', color='orange')

# 予測値
plt.plot(test.index, forecast, label='Forecast', color='green')

# ラベル設定
plt.title('SARIMA Forecast vs Test')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# RMSEの計算
rmse = np.sqrt(mean_squared_error(test['Passengers'], forecast))
print(f"RMSE: {rmse}")

# MAEの計算
mae = np.mean(np.abs(test['Passengers'] - forecast))
print(f"MAE: {mae}")

# MAPEの計算

mape = np.mean(np.abs((test['Passengers'] - forecast) / test['Passengers'])) * 100
print(f"MAPE: {mape}")
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.39140D+00    |proj g|=  6.86568D-02
#
# At iterate    5    f=  3.38797D+00    |proj g|=  3.03804D-02
#
# At iterate   10    f=  3.38299D+00    |proj g|=  2.47865D-02
#
# At iterate   15    f=  3.37783D+00    |proj g|=  4.65660D-03
#  This problem is unconstrained.
# At iterate   20    f=  3.37679D+00    |proj g|=  2.46337D-03
#
# At iterate   25    f=  3.37659D+00    |proj g|=  6.94709D-04
#
# At iterate   30    f=  3.37654D+00    |proj g|=  1.53044D-03
#
# At iterate   35    f=  3.37652D+00    |proj g|=  2.19401D-04
#
# At iterate   40    f=  3.37652D+00    |proj g|=  4.48759D-05
#
# At iterate   45    f=  3.37651D+00    |proj g|=  1.33189D-04
#
# At iterate   50    f=  3.37651D+00    |proj g|=  6.62605D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     60      1     0     0   6.626D-05   3.377D+00
#   F =   3.3765112314647716
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /opt/conda/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                         Passengers   No. Observations:                  132
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -445.699
# Date:                            Sat, 28 Dec 2024   AIC                            901.399
# Time:                                    17:44:07   BIC                            915.295
# Sample:                                         0   HQIC                           907.042
#                                             - 132
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4976      0.312     -1.597      0.110      -1.109       0.113
# ma.L1          0.2583      0.335      0.772      0.440      -0.398       0.915
# ar.S.L12      -0.9995      0.173     -5.790      0.000      -1.338      -0.661
# ma.S.L12       0.9898      1.888      0.524      0.600      -2.710       4.690
# sigma2        98.0935    164.037      0.598      0.550    -223.414     419.601
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.61
# Prob(Q):                              0.97   Prob(JB):                         0.74
# Heteroskedasticity (H):               1.56   Skew:                            -0.06
# Prob(H) (two-sided):                  0.16   Kurtosis:                         3.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# RMSE: 21.18799162854146
# MAE: 16.31766952405532
# MAPE: 3.6782483778430097
